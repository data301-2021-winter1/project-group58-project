# %%
import pandas as pd
data=pd.read_csv("adult-training.csv",sep=",")
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24156/3733940658.py in <module>
# ----> 1 import pandas as pd
#       2 data=pd.read_csv("adult-training.csv",sep=",")
#       3 data
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24156/902919682.py in <module>
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas
pandas._version_
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24156/2892085414.py in <module>
# ----> 1 import pandas
#       2 pandas._version_
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install wheel
pip install pandas
# Out:
#   File "C:\Users\yaoli\AppData\Local\Temp/ipykernel_24156/526407268.py", line 1
#     pip install wheel
#         ^
# SyntaxError: invalid syntax

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4808/3648170110.py in <module>
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas
pandas._version_
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4808/2892085414.py in <module>
# ----> 1 import pandas
#       2 pandas._version_
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
data=pd.read_csv("adult-training.csv",sep=",")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19308/3733940658.py in <module>
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("adult-training.csv",sep=",")
#       3 data
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
data=pd.read_csv("adult-training.csv",sep=",")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19308/3733940658.py in <module>
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("adult-training.csv",sep=",")
#       3 data
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
data=pd.read_csv("adult-training.csv",sep=",")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19308/3733940658.py in <module>
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("adult-training.csv",sep=",")
#       3 data
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
data=pd.read_csv("adult-training.csv",sep=",")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19308/3733940658.py in <module>
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("adult-training.csv",sep=",")
#       3 data
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
df=pd.read_csv("adult-training.csv",sep=",")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19308/1527247425.py in <module>
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("adult-training.csv",sep=",")
#       3 df
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
data=pd.read_csv("adult.csv",sep=",")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19308/3866688872.py in <module>
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("adult.csv",sep=",")
#       3 data
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ## Milestone 3(Group 58)

# %% [markdown]
# ## Li, Yao
#
# ##Student ID:48996664
#
# ##for this project, my research question is about what factor possibly affect adult income. As each county is now developing quickly, adult income has been talked heatedly in the society. Before I proceed into this question and do research, I need to speicify and reorganize those data for having clearer visualizations. Then I try the following code.

# %%
import pandas as pd
df=pd.read_csv("adult.csv",sep=",")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
## After looking at these data, I find that there are two columns seem not relatively useful to the research. So I decide to remove them.
l1=['capital-gain','capital-loss']
df2=df.drop(columns=l1)
df2
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
## After looking at these data, I find that all people are from United-States. So I decide to rempve them.
l2=['native-country']
df3=df2.drop(columns=l2)
df3
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
## After looking at these data, I find that educational-num and education are basically same(by looking at education, you can actually estimate years of education. So I decide to keep education only.
l3=['educational-num']
df4=df3.drop(columns=l3)
df4
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 4       18             ?  103497  Some-college       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship   race  gender  hours-per-week income
# 0      Machine-op-inspct    Own-child  Black    Male              40  <=50K
# ...

# %%
## After looking at these data, I find that workclass and occupation have several missing values and it is not pretty important from my opinion. So I decide to remove them.
l4=['workclass','occupation']
df5=df4.drop(columns=l4)
df5
# Out:
#        age  fnlwgt     education      marital-status relationship   race  \
# 0       25  226802          11th       Never-married    Own-child  Black
# 1       38   89814       HS-grad  Married-civ-spouse      Husband  White
# 2       28  336951    Assoc-acdm  Married-civ-spouse      Husband  White
# 3       44  160323  Some-college  Married-civ-spouse      Husband  Black
# 4       18  103497  Some-college       Never-married    Own-child  White
# ...    ...     ...           ...                 ...          ...    ...
# 48837   27  257302    Assoc-acdm  Married-civ-spouse         Wife  White
# 48838   40  154374       HS-grad  Married-civ-spouse      Husband  White
# 48839   58  151910       HS-grad             Widowed    Unmarried  White
# 48840   22  201490       HS-grad       Never-married    Own-child  White
# 48841   52  287927       HS-grad  Married-civ-spouse         Wife  White
#
#        gender  hours-per-week income
# 0        Male              40  <=50K
# ...

# %%
#Task2: Method chaining

df6=df5.rename(columns={'income':'income(dollar)'})
df6
# Out:
#        age  fnlwgt     education      marital-status relationship   race  \
# 0       25  226802          11th       Never-married    Own-child  Black
# 1       38   89814       HS-grad  Married-civ-spouse      Husband  White
# 2       28  336951    Assoc-acdm  Married-civ-spouse      Husband  White
# 3       44  160323  Some-college  Married-civ-spouse      Husband  Black
# 4       18  103497  Some-college       Never-married    Own-child  White
# ...    ...     ...           ...                 ...          ...    ...
# 48837   27  257302    Assoc-acdm  Married-civ-spouse         Wife  White
# 48838   40  154374       HS-grad  Married-civ-spouse      Husband  White
# 48839   58  151910       HS-grad             Widowed    Unmarried  White
# 48840   22  201490       HS-grad       Never-married    Own-child  White
# 48841   52  287927       HS-grad  Married-civ-spouse         Wife  White
#
#        gender  hours-per-week income(dollar)
# 0        Male              40          <=50K
# ...

# %%
#Method chaining
#define a new method
def lp(url_or_path_to_csv_file):
    DF=(pd.read_csv("adult.csv",sep=",",decimal=',')
#rename columns
        .rename(columns={'income':'income(dollar)'})   
#drop several unimportant columns
        .drop(columns=['capital-gain','capital-loss','native-country','educational-num','workclass','workclass','occupation']))
    return DF

# %% [markdown]
# #Above codes are to rename the columns, throw out the columns and rows that contain missing values, dropping  some relatively useless columns to make the data clearer. For example, I dropped "capital-gain and loss", because they are not important to adult come and their values are all 0 basically. The detailed explanation is provided in each cell above. The following data frame is what it looks like after the operation.

# %%
lp("adult.csv")
# Out:
#        age  fnlwgt     education      marital-status relationship   race  \
# 0       25  226802          11th       Never-married    Own-child  Black
# 1       38   89814       HS-grad  Married-civ-spouse      Husband  White
# 2       28  336951    Assoc-acdm  Married-civ-spouse      Husband  White
# 3       44  160323  Some-college  Married-civ-spouse      Husband  Black
# 4       18  103497  Some-college       Never-married    Own-child  White
# ...    ...     ...           ...                 ...          ...    ...
# 48837   27  257302    Assoc-acdm  Married-civ-spouse         Wife  White
# 48838   40  154374       HS-grad  Married-civ-spouse      Husband  White
# 48839   58  151910       HS-grad             Widowed    Unmarried  White
# 48840   22  201490       HS-grad       Never-married    Own-child  White
# 48841   52  287927       HS-grad  Married-civ-spouse         Wife  White
#
#        gender  hours-per-week income(dollar)
# 0        Male              40          <=50K
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df6
# Out:
#        age  fnlwgt     education      marital-status relationship   race  \
# 0       25  226802          11th       Never-married    Own-child  Black
# 1       38   89814       HS-grad  Married-civ-spouse      Husband  White
# 2       28  336951    Assoc-acdm  Married-civ-spouse      Husband  White
# 3       44  160323  Some-college  Married-civ-spouse      Husband  Black
# 4       18  103497  Some-college       Never-married    Own-child  White
# ...    ...     ...           ...                 ...          ...    ...
# 48837   27  257302    Assoc-acdm  Married-civ-spouse         Wife  White
# 48838   40  154374       HS-grad  Married-civ-spouse      Husband  White
# 48839   58  151910       HS-grad             Widowed    Unmarried  White
# 48840   22  201490       HS-grad       Never-married    Own-child  White
# 48841   52  287927       HS-grad  Married-civ-spouse         Wife  White
#
#        gender  hours-per-week income(dollar)
# 0        Male              40          <=50K
# ...

# %%
plt.figure(figsize=(13,8))
sns.barplot(x='education',y='hours-per-week',data=df6)
##There are not showing that the better education people take, the shorter time people work on.
# Out:
# <AxesSubplot:xlabel='education', ylabel='hours-per-week'>

# %% [markdown]
# #To make the graph clearer, I choose to use barplot to the press the relationship between education and hours-per-week(education level that people take and hours people work per week). The graph looks relatively average, because the differences among those peaks are not quite significant. This is showing that it is not necessary that people would not work less if they were with higher education level.

# %%
df6
# Out:
#        age  fnlwgt     education      marital-status relationship   race  \
# 0       25  226802          11th       Never-married    Own-child  Black
# 1       38   89814       HS-grad  Married-civ-spouse      Husband  White
# 2       28  336951    Assoc-acdm  Married-civ-spouse      Husband  White
# 3       44  160323  Some-college  Married-civ-spouse      Husband  Black
# 4       18  103497  Some-college       Never-married    Own-child  White
# ...    ...     ...           ...                 ...          ...    ...
# 48837   27  257302    Assoc-acdm  Married-civ-spouse         Wife  White
# 48838   40  154374       HS-grad  Married-civ-spouse      Husband  White
# 48839   58  151910       HS-grad             Widowed    Unmarried  White
# 48840   22  201490       HS-grad       Never-married    Own-child  White
# 48841   52  287927       HS-grad  Married-civ-spouse         Wife  White
#
#        gender  hours-per-week income(dollar)
# 0        Male              40          <=50K
# ...

# %%
plt.figure(figsize=(14,9))
sns.barplot(x='income(dollar)',y='hours-per-week',data=df6)
# Out:
# <AxesSubplot:xlabel='income(dollar)', ylabel='hours-per-week'>

# %% [markdown]
# #This graph simply is made up of hours-per-week and income(hours that people work per week and the income they have). And it directly shows that the more time and effort employees put in, the higher income they will have.

# %%
plt.figure(figsize=(10,8))
finalweight = df6.corr()
sns.heatmap(finalweight, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #In this heatmap, those numbers are stored in these squares indicates indexes of the correlation among hours-per-week, fnlwgt,age, and the numbers should be closer to 1(in my case, it is apparently not). Technically, the closer the number is, the higher possibility two variables having a linear relationship. However, positive and negative number do exist in the graph, those negative numbers stand for the inverse relationship, which simply means that as one of these variable getting larger, the other will become smaller(just like inverse proportional function y=1/x). And positive numbers stand for positive relationship like y=2x, as a number is getting larger, the other variable will become larger either. At this point, it is not hard to find that coefficient between hours-per week and age is positive, although it is quite snmall. Moreover, the coefficient between fwlwgt and age, the coefficient between hours-per-week and fnlwgt are negative, and the former is much closer to the latter. Therefore, I think all three have no linear relation for having extreme small numbers.

# %% [markdown]
# #In conclusion, while analyzing those data and data types, I find that some variables are not related togther for having a valuable graph. For example, final weight(fnlwgt) somehow icnluding the features of age and race. So age and race do not play a huge role of analyze the adult income issue(they can not even have a linear relationship). In further research, I sould add occupation back and analyze the significance between it and income. It should give a more reliable and proportional statistics.
